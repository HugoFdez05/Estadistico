# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# En primer lugar realizamos una lectura y exploración inicial del dataset

# %%
df = pd.read_csv("C:/Users/hfdez/Python/Proyecto I/activaciones_samur_2024.csv", sep=";")
df
# Out:
#         Año    Mes Hora Solicitud Hora Intervención  \
# 0      2024  ENERO        0:03:49           0:06:39
# 1      2023  ENERO        0:05:55           0:20:38
# 2      2023  ENERO        0:05:55           0:20:38
# 3      2024  ENERO        0:16:34           0:21:20
# 4      2024  ENERO        0:17:12               NaN
# ...     ...    ...            ...               ...
# 35408  2024  MARZO       23:51:17               NaN
# 35409  2024  MARZO       23:57:12           0:06:59
# 35410  2024  MARZO       23:58:27           0:03:56
# 35411  2024  MARZO            NaN               NaN
# 35412  2024  MARZO            NaN               NaN
#
#                                               Código           Distrito  \
# 0                                            Heridas           CHAMBERI
# 1      Atención psicológica a Familiares y allegados      CIUDAD LINEAL
# 2                      Inconsciente sin filiar causa      CIUDAD LINEAL
# 3                             Patología respiratoria           CHAMBERI
# 4                           Agresión sin especificar             CENTRO
# ...                                              ...                ...
# 35408                                          Otros          CHAMARTIN
# 35409                           Intoxicación etílica                NaN
# 35410                     Certificación psiquiátrico      CIUDAD LINEAL
# 35411                                        Heridas             CENTRO
# 35412                       Patología cardiovascular  VILLA DE VALLECAS
#
#                  Hospital
# 0                  La Paz
# 1                     NaN
# 2                     NaN
# 3      Clínico San Carlos
# 4                     NaN
# ...                   ...
# 35408                 NaN
# 35409         La Princesa
# 35410    Gregorio Marañón
# 35411                 NaN
# 35412                 NaN
#
# [35413 rows x 7 columns]

# %%
# Lista de hospitales específicos que me interesa seleccionar
hospitales_seleccionados = ["La Paz", "Gregorio Marañón", "Doce de Octubre", "Ramón y Cajal"]
# Filtramos el dataset unicamente para nuestros 4 hospitales
df_filtrado = df[df['Hospital'].isin(hospitales_seleccionados)]

# Mostramos el dataset filtrado
df_filtrado
# Out:
#         Año    Mes Hora Solicitud Hora Intervención  \
# 0      2024  ENERO        0:03:49           0:06:39
# 15     2024  ENERO        0:49:33           0:56:20
# 24     2024  ENERO        1:22:56           1:36:19
# 25     2024  ENERO        1:23:18           1:23:18
# 28     2024  ENERO        1:32:56           1:38:10
# ...     ...    ...            ...               ...
# 35394  2024  MARZO       22:14:11          22:19:44
# 35399  2024  MARZO       22:41:12          22:48:14
# 35400  2024  MARZO       22:45:34          22:51:36
# 35402  2024  MARZO       22:54:50          23:01:35
# 35410  2024  MARZO       23:58:27           0:03:56
#
#                            Código       Distrito          Hospital
# 0                         Heridas       CHAMBERI            La Paz
# 15                        Quemado  VALLECAS PTE.  Gregorio Marañón
# 24                   Orden medica  CIUDAD LINEAL     Ramón y Cajal
# 25             Casual: caída, etc         TETUAN            La Paz
# 28             Casual: caída, etc      SALAMANCA  Gregorio Marañón
# ...                           ...            ...               ...
# 35394                     Heridas         RETIRO  Gregorio Marañón
# 35399      Accidente de bicicleta  VALLECAS PTE.  Gregorio Marañón
# 35400    Convulsión y/o epilepsia         CENTRO  Gregorio Marañón
# 35402                       Otros     ARGANZUELA  Gregorio Marañón
# 35410  Certificación psiquiátrico  CIUDAD LINEAL  Gregorio Marañón
#
# [6767 rows x 7 columns]

# %%
# Mostramos las primeras filas del dataset
print("Primeras filas del dataset:")
df_filtrado.head()
# Out:
# Primeras filas del dataset:
#      Año    Mes Hora Solicitud Hora Intervención              Código  \
# 0   2024  ENERO        0:03:49           0:06:39             Heridas
# 15  2024  ENERO        0:49:33           0:56:20             Quemado
# 24  2024  ENERO        1:22:56           1:36:19        Orden medica
# 25  2024  ENERO        1:23:18           1:23:18  Casual: caída, etc
# 28  2024  ENERO        1:32:56           1:38:10  Casual: caída, etc
#
#          Distrito          Hospital
# 0        CHAMBERI            La Paz
# 15  VALLECAS PTE.  Gregorio Marañón
# 24  CIUDAD LINEAL     Ramón y Cajal
# 25         TETUAN            La Paz
# 28      SALAMANCA  Gregorio Marañón

# %%
# Mostramos las últimas filas del dataset
print("\nÚltimas filas del dataset:")
df_filtrado.tail()
# Out:
# Últimas filas del dataset:
#         Año    Mes Hora Solicitud Hora Intervención  \
# 35394  2024  MARZO       22:14:11          22:19:44
# 35399  2024  MARZO       22:41:12          22:48:14
# 35400  2024  MARZO       22:45:34          22:51:36
# 35402  2024  MARZO       22:54:50          23:01:35
# 35410  2024  MARZO       23:58:27           0:03:56
#
#                            Código       Distrito          Hospital
# 35394                     Heridas         RETIRO  Gregorio Marañón
# 35399      Accidente de bicicleta  VALLECAS PTE.  Gregorio Marañón
# 35400    Convulsión y/o epilepsia         CENTRO  Gregorio Marañón
# 35402                       Otros     ARGANZUELA  Gregorio Marañón
# 35410  Certificación psiquiátrico  CIUDAD LINEAL  Gregorio Marañón

# %%
#Sacamos la información general del dataset y obtenemos el número de filas y columnas
rows, columns = df_filtrado.shape
print(f"Número de filas: {rows}")
print(f"Número de columnas: {columns}")

# Obtenemos información general del dataset
info = df_filtrado.info()

# Obtenemos tipos de datos de cada columna
data_types = df_filtrado.dtypes
print(data_types)
# Out:
# Número de filas: 6767
# Número de columnas: 7
# <class 'pandas.core.frame.DataFrame'>
# Index: 6767 entries, 0 to 35410
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Año                6767 non-null   int64
#  1   Mes                6767 non-null   object
#  2   Hora Solicitud     6767 non-null   object
#  3   Hora Intervención  6767 non-null   object
#  4   Código             6762 non-null   object
#  5   Distrito           6744 non-null   object
#  6   Hospital           6767 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 422.9+ KB
# Año                   int64
# Mes                  object
# Hora Solicitud       object
# Hora Intervención    object
# Código               object
# Distrito             object
# Hospital             object
# dtype: object

# %% [markdown]
# A continuación se hace una limpieza y un preprocesamiento de datos

# %%
#Nos aseguramos de que el tipo de datos sea adecuado en cada caso

def convertir_tipos_de_datos(df_filtrado):
    # Convertimos la colimna Año a entero
    df_filtrado['Año'] = df_filtrado['Año'].astype(int)

    # Convertimos la columna Mes a categoría
    df_filtrado['Mes'] = df_filtrado['Mes'].astype('category')

    # Convertimos las columnas Hora Solicitud y Hora Intervención a tipo datetime
    df_filtrado['Hora Solicitud'] = pd.to_datetime(df_filtrado['Hora Solicitud'], format='%H:%M:%S', errors='coerce')
    df_filtrado['Hora Intervención'] = pd.to_datetime(df_filtrado['Hora Intervención'], format='%H:%M:%S', errors='coerce')

    # Convertimos las columnas Código, Distrito y Hospital a cadenas
    df_filtrado['Código'] = df_filtrado['Código'].astype(str)
    df_filtrado['Distrito'] = df_filtrado['Distrito'].astype(str)
    df_filtrado['Hospital'] = df_filtrado['Hospital'].astype(str)

    return df_filtrado

# Verificamos como queda el dataset después de la conversión
print(df_filtrado.dtypes)
df_filtrado
# Out:
# Año                   int64
# Mes                  object
# Hora Solicitud       object
# Hora Intervención    object
# Código               object
# Distrito             object
# Hospital             object
# dtype: object
#         Año    Mes Hora Solicitud Hora Intervención  \
# 0      2024  ENERO        0:03:49           0:06:39
# 15     2024  ENERO        0:49:33           0:56:20
# 24     2024  ENERO        1:22:56           1:36:19
# 25     2024  ENERO        1:23:18           1:23:18
# 28     2024  ENERO        1:32:56           1:38:10
# ...     ...    ...            ...               ...
# 35394  2024  MARZO       22:14:11          22:19:44
# 35399  2024  MARZO       22:41:12          22:48:14
# 35400  2024  MARZO       22:45:34          22:51:36
# 35402  2024  MARZO       22:54:50          23:01:35
# 35410  2024  MARZO       23:58:27           0:03:56
#
#                            Código       Distrito          Hospital
# 0                         Heridas       CHAMBERI            La Paz
# 15                        Quemado  VALLECAS PTE.  Gregorio Marañón
# 24                   Orden medica  CIUDAD LINEAL     Ramón y Cajal
# 25             Casual: caída, etc         TETUAN            La Paz
# 28             Casual: caída, etc      SALAMANCA  Gregorio Marañón
# ...                           ...            ...               ...
# 35394                     Heridas         RETIRO  Gregorio Marañón
# 35399      Accidente de bicicleta  VALLECAS PTE.  Gregorio Marañón
# 35400    Convulsión y/o epilepsia         CENTRO  Gregorio Marañón
# 35402                       Otros     ARGANZUELA  Gregorio Marañón
# 35410  Certificación psiquiátrico  CIUDAD LINEAL  Gregorio Marañón
#
# [6767 rows x 7 columns]

# %%
# Creamos un diccionario de mapeo para reemplazar los nombres de los meses por números
meses_map = {
    'ENERO': 1,
    'FEBRERO': 2,
    'MARZO': 3,
}

# Aplicamos el reemplazo usando el método replace
df_filtrado['Mes'] = df_filtrado['Mes'].replace(meses_map)

# Imprimimos el dataset actualizado
df_filtrado
# Out:
# C:\Users\hfdez\AppData\Local\Temp\ipykernel_5688\2812132671.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Mes'] = df_filtrado['Mes'].replace(meses_map)
#         Año  Mes Hora Solicitud Hora Intervención                      Código  \
# 0      2024    1        0:03:49           0:06:39                     Heridas
# 15     2024    1        0:49:33           0:56:20                     Quemado
# 24     2024    1        1:22:56           1:36:19                Orden medica
# 25     2024    1        1:23:18           1:23:18          Casual: caída, etc
# 28     2024    1        1:32:56           1:38:10          Casual: caída, etc
# ...     ...  ...            ...               ...                         ...
# 35394  2024    3       22:14:11          22:19:44                     Heridas
# 35399  2024    3       22:41:12          22:48:14      Accidente de bicicleta
# 35400  2024    3       22:45:34          22:51:36    Convulsión y/o epilepsia
# 35402  2024    3       22:54:50          23:01:35                       Otros
# 35410  2024    3       23:58:27           0:03:56  Certificación psiquiátrico
#
#             Distrito          Hospital
# 0           CHAMBERI            La Paz
# 15     VALLECAS PTE.  Gregorio Marañón
# 24     CIUDAD LINEAL     Ramón y Cajal
# 25            TETUAN            La Paz
# 28         SALAMANCA  Gregorio Marañón
# ...              ...               ...
# 35394         RETIRO  Gregorio Marañón
# 35399  VALLECAS PTE.  Gregorio Marañón
# 35400         CENTRO  Gregorio Marañón
# 35402     ARGANZUELA  Gregorio Marañón
# 35410  CIUDAD LINEAL  Gregorio Marañón
#
# [6767 rows x 7 columns]

# %%
# Debido a que no se pueden calcular estadisticas con strings creamos una función para convertir una cadena HH:MM:SS a horas decimales
def convertir_a_horas_decimales(hora_str):
    try:                                    #Añadimos un try-except para manejar los valores no válidos que no se puedan convertir
        partes = hora_str.split(':')
        horas = int(partes[0])
        minutos = int(partes[1])
        segundos = int(partes[2])
        return horas + minutos / 60 + segundos / 3600
    except AttributeError: 
        return None

# Limpiamos y convertimos los datos
df_filtrado['Hora Solicitud'] = df_filtrado['Hora Solicitud'].astype(str)
df_filtrado['Hora Intervención'] = df_filtrado['Hora Intervención'].astype(str)

# Convertimos las columnas 'Hora Solicitud' y 'Hora Intervención' a horas decimales
df_filtrado['Hora Solicitud Decimal'] = df_filtrado['Hora Solicitud'].apply(convertir_a_horas_decimales)
df_filtrado['Hora Intervención Decimal'] = df_filtrado['Hora Intervención'].apply(convertir_a_horas_decimales)
# Out:
# C:\Users\hfdez\AppData\Local\Temp\ipykernel_5688\621592816.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Hora Solicitud'] = df_filtrado['Hora Solicitud'].astype(str)
# C:\Users\hfdez\AppData\Local\Temp\ipykernel_5688\621592816.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Hora Intervención'] = df_filtrado['Hora Intervención'].astype(str)
# C:\Users\hfdez\AppData\Local\Temp\ipykernel_5688\621592816.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Hora Solicitud Decimal'] = df_filtrado['Hora Solicitud'].apply(convertir_a_horas_decimales)
# C:\Users\hfdez\AppData\Local\Temp\ipykernel_5688\621592816.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Hora Intervención Decimal'] = df_filtrado['Hora Intervención'].apply(convertir_a_horas_decimales)

# %%
# Identificamos los valores faltantes NaN usando la moda/media para reemplazarlos y aquellos datos por encima o por debajo de dos desviaciones típicas de la media los imputamos por la moda/media.

def imputar_nan_y_outliers(df_filtrado):
    # Imputamos NaN con la moda o la media
    for col in df_filtrado.columns:
        if df_filtrado[col].dtype in [np.int64, np.float64]:
            if df_filtrado[col].isnull().any():
                moda = df_filtrado[col].mode()[0]
                media = df_filtrado[col].mean()
                df_filtrado[col].fillna(moda if pd.notnull(moda) else media, inplace=True)

    # Imputamos valores fuera de ±2 desviaciones estándar de la media
    for col in ['Hora Solicitud', 'Hora Intervención']:
        std = df_filtrado[col].std()
        mean = df_filtrado[col].mean()
        lower_bound = mean - 2 * std
        upper_bound = mean + 2 * std

        df_filtrado.loc[df_filtrado[col] < lower_bound, col] = mean
        df_filtrado.loc[df_filtrado[col] > upper_bound, col] = mean

    return df_filtrado

# Verificamo como queda el dataset después de la imputación
df_filtrado
# Out:
#         Año  Mes Hora Solicitud Hora Intervención                      Código  \
# 0      2024    1        0:03:49           0:06:39                     Heridas
# 15     2024    1        0:49:33           0:56:20                     Quemado
# 24     2024    1        1:22:56           1:36:19                Orden medica
# 25     2024    1        1:23:18           1:23:18          Casual: caída, etc
# 28     2024    1        1:32:56           1:38:10          Casual: caída, etc
# ...     ...  ...            ...               ...                         ...
# 35394  2024    3       22:14:11          22:19:44                     Heridas
# 35399  2024    3       22:41:12          22:48:14      Accidente de bicicleta
# 35400  2024    3       22:45:34          22:51:36    Convulsión y/o epilepsia
# 35402  2024    3       22:54:50          23:01:35                       Otros
# 35410  2024    3       23:58:27           0:03:56  Certificación psiquiátrico
#
#             Distrito          Hospital  Hora Solicitud Decimal  \
# 0           CHAMBERI            La Paz                0.063611
# 15     VALLECAS PTE.  Gregorio Marañón                0.825833
# 24     CIUDAD LINEAL     Ramón y Cajal                1.382222
# 25            TETUAN            La Paz                1.388333
# 28         SALAMANCA  Gregorio Marañón                1.548889
# ...              ...               ...                     ...
# 35394         RETIRO  Gregorio Marañón               22.236389
# 35399  VALLECAS PTE.  Gregorio Marañón               22.686667
# 35400         CENTRO  Gregorio Marañón               22.759444
# 35402     ARGANZUELA  Gregorio Marañón               22.913889
# 35410  CIUDAD LINEAL  Gregorio Marañón               23.974167
#
#        Hora Intervención Decimal
# 0                       0.110833
# 15                      0.938889
# 24                      1.605278
# 25                      1.388333
# 28                      1.636111
# ...                          ...
# 35394                  22.328889
# 35399                  22.803889
# 35400                  22.860000
# 35402                  23.026389
# 35410                   0.065556
#
# [6767 rows x 9 columns]
